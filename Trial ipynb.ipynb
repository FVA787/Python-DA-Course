# %%
all_strings = []
my_string = int(input('Введите число: '))
while my_string != 23:
	if my_string != 0:
		all_strings.append(my_string)    
	my_string = int(input('Введите число: '))
print(sum(all_strings)) ## the very first comment
