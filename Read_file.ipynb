# %%
f = open(r'C:\Users\fomichevva4\Desktop\Python_DA_Course\Работа с файлами\visit_log.csv', 'r', encoding='utf-8')
i = 0
for line in f:
    print(line)
    i += 1
    if i > 10:
        break
# Out:
# user_id,source
#
# 6450655ae8,other
#
# b4ea53e670,other
#
# 0e37347152,other
#
# 96064ae9e0,other
#
# e1bd168161,context
#
# 71bcf169b4,other
#
# e0aee73c5d,other
#
# 1f8845e157,context
#
# 78d22c5c78,other
